# %%
# pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid ="70739307db3e428cbcff6639e00832cb" 
secret = "2b317a42cbbc4a1c833c0ec33d8f0614"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
result = sp.category_playlists(category_id='punjabi',country='IN')

# %%
result
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/punjabi/playlists?country=IN&offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'The ultimate 101 hits. Cover: Maninder Buttar',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5cZuAHLNjGz'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5cZuAHLNjGz',
#     'id': '37i9dQZF1DX5cZuAHLNjGz',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000283f30697b0b771280af51c71',
#       'width': None}],
#     'name': 'Punjabi 101',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
# ...

# %%
result1 = sp.categories(country='IN',locale="hin_IN")

# %%
result1
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?country=IN&offset=0&limit=20',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/at_home',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/04da469dd7be4dab96659aa1fa9f0ac9.jpeg',
#       'width': None}],
#     'id': 'at_home',
#     'name': 'At Home'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/pop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'pop',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/summer',
# ...

# %%
track_results = sp.search(q='year:2020', type='track',market="IN")

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2020&type=track&market=IN&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0y59o4v8uw5crbN9M3JiL1'},
#        'href': 'https://api.spotify.com/v1/artists/0y59o4v8uw5crbN9M3JiL1',
#        'id': '0y59o4v8uw5crbN9M3JiL1',
#        'name': 'Badshah',
#        'type': 'artist',
#        'uri': 'spotify:artist:0y59o4v8uw5crbN9M3JiL1'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wGiiYsZ5QR9vj3fa0L7UV'},
#      'href': 'https://api.spotify.com/v1/albums/4wGiiYsZ5QR9vj3fa0L7UV',
#      'id': '4wGiiYsZ5QR9vj3fa0L7UV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731236f9aabbd45bf852bdbd9c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021236f9aabbd45bf852bdbd9c',
#        'width': 300},
# ...

# %%
album=sp.album('4wGiiYsZ5QR9vj3fa0L7UV')
album
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0y59o4v8uw5crbN9M3JiL1'},
#    'href': 'https://api.spotify.com/v1/artists/0y59o4v8uw5crbN9M3JiL1',
#    'id': '0y59o4v8uw5crbN9M3JiL1',
#    'name': 'Badshah',
#    'type': 'artist',
#    'uri': 'spotify:artist:0y59o4v8uw5crbN9M3JiL1'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
# ...
